# %%
import subprocess
import os
import time
import pandas as pd
from Bio import SeqIO
from Bio import pairwise2

def compute_alignment_score(seq1, seq2):
    alignments = pairwise2.align.globalxx(seq1.seq, seq2.seq, one_alignment_only=True)
    if alignments:
        alignment = alignments[0]
        return alignment.score
    else:
        return 0  # No alignment found, score is 0

def run_command(command):
    print(f"Running command: {command}")
    start_time = time.time()
    result = subprocess.run(command, shell=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, universal_newlines=True)
    elapsed_time = time.time() - start_time
    print(f"Command '{command}' took {elapsed_time:.2f} seconds to run.")
    if result.stdout:
        print(result.stdout)
    if result.stderr:
        print("Error:", result.stderr)
    return result, elapsed_time

def select_best_alignment(sequences, query_sequence):
    best_sequence = None
    best_score = 0

    for sequence in sequences:
        alignment_score = compute_alignment_score(sequence, query_sequence)  # Implement this function to compute alignment score
        if alignment_score > best_score:
            best_score = alignment_score
            best_sequence = sequence

    return best_sequence

def split_fastq(input_path, output_dir, base_name, percentile=20):
    # Read sequences and sort by length
    sequences = list(SeqIO.parse(input_path, "fastq"))
    sequences.sort(key=lambda x: len(x), reverse=True)

    # Split into top percentile and remaining sequences
    split_index = len(sequences) * percentile // 100
    top_sequences = sequences[:split_index]
    remaining_sequences = sequences[split_index:]

    # Write to separate files
    top_sequences_path = os.path.join(output_dir, f"{base_name}_top{percentile}.fastq")
    remaining_sequences_path = os.path.join(output_dir, f"{base_name}_remaining{100-percentile}.fastq")
    SeqIO.write(top_sequences, top_sequences_path, "fastq")
    SeqIO.write(remaining_sequences, remaining_sequences_path, "fastq")

    return top_sequences_path, remaining_sequences_path

def main():
    input_fastq_filename = "rbcL_Qiagen_tomato_5000.fastq"
    input_fastq_path = f"assets/input/{input_fastq_filename}"
    base_name = os.path.splitext(input_fastq_filename)[0]

    output_base_dir = "assets/output"
    output_dir = os.path.join(output_base_dir, base_name)
    os.makedirs(output_dir, exist_ok=True)

    total_time_taken = 0

    # Split the file into top 20% and remaining 80%
    top_sequences_path, remaining_sequences_path = split_fastq(input_fastq_path, output_dir, base_name, percentile=20)

    # Step 1: Align and generate consensus from top 20% sequences
    top_paf_path = os.path.join(output_dir, f"{base_name}_top20_reads.paf")
    top_consensus_path = os.path.join(output_dir, f"{base_name}_top20_consensus.fasta")
    minimap2_command = f"minimap2 -x ava-ont {top_sequences_path} {top_sequences_path} > {top_paf_path}"
    print("Running read alignment with minimap2 on top 20% sequences...")
    _, minimap2_time = run_command(minimap2_command)
    total_time_taken += minimap2_time

    racon_command = f"racon -m 8 -x -6 -g -8 -w 500 {top_sequences_path} {top_paf_path} {top_sequences_path} > {top_consensus_path}"
    print("Generating consensus sequence with racon on top 20% sequences...")
    _, racon_time = run_command(racon_command)
    total_time_taken += racon_time

    # Step 1 bis: If the outputed racon file contains more than one sequence, we take the longest one
    consensus_sequences = list(SeqIO.parse(top_consensus_path, "fasta"))
    if len(consensus_sequences) > 1:
        print(f"Multiple sequences found in {top_consensus_path}. Selecting the best alignment...")
        best_sequence = select_best_alignment(consensus_sequences, consensus_sequences[0])  # Choose the first sequence as the reference
        SeqIO.write(best_sequence, top_consensus_path, "fasta")

    # Step 2: Align the remaining 80% sequences to the top 20% consensus
    remaining_paf_path = os.path.join(output_dir, f"{base_name}_remaining80_reads.paf")
    final_consensus_path = os.path.join(output_dir, f"{base_name}_final_consensus.fasta")
    minimap2_command = f"minimap2 -x map-ont {top_consensus_path} {remaining_sequences_path} > {remaining_paf_path}"
    print("Running read alignment with minimap2 on remaining 80% sequences...")
    _, minimap2_time = run_command(minimap2_command)
    total_time_taken += minimap2_time

    # Step 3: Generate the final consensus sequence with racon
    racon_command = f"racon -m 8 -x -6 -g -8 -w 500 {remaining_sequences_path} {remaining_paf_path} {top_consensus_path} > {final_consensus_path}"
    print("Generating final consensus sequence with racon...")
    _, racon_time = run_command(racon_command)
    total_time_taken += racon_time

    # Print out the total time for each step
    print(f"Minimap2 alignment took {minimap2_time:.2f} seconds.")
    print(f"Total Racon iterations took {total_time_taken - minimap2_time:.2f} seconds.")

    # Print out the total time for the pipeline
    print(f"Total time taken for the pipeline: {total_time_taken:.2f} seconds.")

main()
# Out:
# Running read alignment with minimap2 on top 20% sequences...
# Running command: minimap2 -x ava-ont assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_top20.fastq assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_top20.fastq > assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_top20_reads.paf
# Command 'minimap2 -x ava-ont assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_top20.fastq assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_top20.fastq > assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_top20_reads.paf' took 2.84 seconds to run.
# Error: [M::mm_idx_gen::0.024*1.20] collected minimizers
# [M::mm_idx_gen::0.038*1.84] sorted minimizers
# [M::main::0.038*1.83] loaded/built the index for 1000 target sequence(s)
# [M::mm_mapopt_update::0.040*1.78] mid_occ = 608
# [M::mm_idx_stat] kmer size: 15; skip: 5; is_hpc: 0; #seq: 1000
# [M::mm_idx_stat::0.041*1.76] distinct minimizers: 61942 (78.57% are singletons); average occurrences: 3.831; average spacing: 2.966; total length: 703802
# [M::worker_pipeline::2.794*2.70] mapped 1000 sequences
# [M::main] Version: 2.22-r1101
# [M::main] CMD: minimap2 -x ava-ont assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_top20.fastq assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_top20.fastq
# [M::main] Real time: 2.798 sec; CPU: 7.554 sec; Peak RSS: 0.074 GB
#
# Generating consensus sequence with racon on top 20% sequences...
# Running command: racon -m 8 -x -6 -g -8 -w 500 assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_top20.fastq assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_top20_reads.paf assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_top20.fastq > assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_top20_consensus.fasta
# Command 'racon -m 8 -x -6 -g -8 -w 500 assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_top20.fastq assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_top20_reads.paf assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_top20.fastq > assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_top20_consensus.fasta' took 2.74 seconds to run.
# Error: [racon::Polisher::initialize] loaded target sequences 0.007375 s
# [racon::Polisher::initialize] loaded sequences 0.007687 s
# [racon::Polisher::initialize] loaded overlaps 0.591344 s
# [racon::Polisher::initialize] aligning overlaps [=>                  ] 0.006066 s
# [racon::Polisher::initialize] aligning overlaps [==>                 ] 0.010291 s
# [racon::Polisher::initialize] aligning overlaps [===>                ] 0.014380 s
# [racon::Polisher::initialize] aligning overlaps [====>               ] 0.018647 s
# [racon::Polisher::initialize] aligning overlaps [=====>              ] 0.022838 s
# [racon::Polisher::initialize] aligning overlaps [======>             ] 0.027150 s
# [racon::Polisher::initialize] aligning overlaps [=======>            ] 0.031470 s
# [racon::Polisher::initialize] aligning overlaps [========>           ] 0.035740 s
# [racon::Polisher::initialize] aligning overlaps [=========>          ] 0.040056 s
# [racon::Polisher::initialize] aligning overlaps [==========>         ] 0.044383 s
# [racon::Polisher::initialize] aligning overlaps [===========>        ] 0.048691 s
# [racon::Polisher::initialize] aligning overlaps [============>       ] 0.052924 s
# [racon::Polisher::initialize] aligning overlaps [=============>      ] 0.057114 s
# [racon::Polisher::initialize] aligning overlaps [==============>     ] 0.061240 s
# [racon::Polisher::initialize] aligning overlaps [===============>    ] 0.065370 s
# [racon::Polisher::initialize] aligning overlaps [================>   ] 0.069509 s
# [racon::Polisher::initialize] aligning overlaps [=================>  ] 0.073435 s
# [racon::Polisher::initialize] aligning overlaps [==================> ] 0.077361 s
# [racon::Polisher::initialize] aligning overlaps [===================>] 0.081241 s
# [racon::Polisher::initialize] aligning overlaps [====================] 0.085870 s
# [racon::Polisher::initialize] transformed data into windows 0.008882 s
# [racon::Polisher::polish] generating consensus [=>                  ] 1.244877 s
# [racon::Polisher::polish] generating consensus [==>                 ] 1.796438 s
# [racon::Polisher::polish] generating consensus [===>                ] 1.923841 s
# [racon::Polisher::polish] generating consensus [====>               ] 1.938595 s
# [racon::Polisher::polish] generating consensus [=====>              ] 1.950882 s
# [racon::Polisher::polish] generating consensus [======>             ] 1.951090 s
# [racon::Polisher::polish] generating consensus [=======>            ] 1.961098 s
# [racon::Polisher::polish] generating consensus [========>           ] 1.965399 s
# [racon::Polisher::polish] generating consensus [=========>          ] 1.965505 s
# [racon::Polisher::polish] generating consensus [==========>         ] 1.965602 s
# [racon::Polisher::polish] generating consensus [===========>        ] 1.973723 s
# [racon::Polisher::polish] generating consensus [============>       ] 1.973975 s
# [racon::Polisher::polish] generating consensus [=============>      ] 1.978120 s
# [racon::Polisher::polish] generating consensus [==============>     ] 1.978378 s
# [racon::Polisher::polish] generating consensus [===============>    ] 1.978670 s
# [racon::Polisher::polish] generating consensus [================>   ] 1.978860 s
# [racon::Polisher::polish] generating consensus [=================>  ] 1.981993 s
# [racon::Polisher::polish] generating consensus [==================> ] 1.986165 s
# [racon::Polisher::polish] generating consensus [===================>] 1.986288 s
# [racon::Polisher::polish] generating consensus [====================] 1.990504 s
# [racon::Polisher::] total = 2.692570 s
#
# Multiple sequences found in assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_top20_consensus.fasta. Selecting the best alignment...
# Running read alignment with minimap2 on remaining 80% sequences...
# Running command: minimap2 -x map-ont assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_top20_consensus.fasta assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_remaining80.fastq > assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_remaining80_reads.paf
# Command 'minimap2 -x map-ont assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_top20_consensus.fasta assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_remaining80.fastq > assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_remaining80_reads.paf' took 0.07 seconds to run.
# Error: [M::mm_idx_gen::0.001*8.42] collected minimizers
# [M::mm_idx_gen::0.001*5.40] sorted minimizers
# [M::main::0.001*5.36] loaded/built the index for 1 target sequence(s)
# [M::mm_mapopt_update::0.001*5.22] mid_occ = 10
# [M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 1
# [M::mm_idx_stat::0.001*5.09] distinct minimizers: 130 (100.00% are singletons); average occurrences: 1.000; average spacing: 6.031; total length: 784
# [M::worker_pipeline::0.025*2.25] mapped 4000 sequences
# [M::main] Version: 2.22-r1101
# [M::main] CMD: minimap2 -x map-ont assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_top20_consensus.fasta assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_remaining80.fastq
# [M::main] Real time: 0.026 sec; CPU: 0.057 sec; Peak RSS: 0.006 GB
#
# Generating final consensus sequence with racon...
# Running command: racon -m 8 -x -6 -g -8 -w 500 assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_remaining80.fastq assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_remaining80_reads.paf assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_top20_consensus.fasta > assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_final_consensus.fasta
# Command 'racon -m 8 -x -6 -g -8 -w 500 assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_remaining80.fastq assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_remaining80_reads.paf assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_top20_consensus.fasta > assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_final_consensus.fasta' took 9.01 seconds to run.
# Error: [racon::Polisher::initialize] loaded target sequences 0.000057 s
# [racon::Polisher::initialize] loaded sequences 0.017786 s
# [racon::Polisher::initialize] loaded overlaps 0.005886 s
# [racon::Polisher::initialize] aligning overlaps [=>                  ] 0.025914 s
# [racon::Polisher::initialize] aligning overlaps [==>                 ] 0.034357 s
# [racon::Polisher::initialize] aligning overlaps [===>                ] 0.042700 s
# [racon::Polisher::initialize] aligning overlaps [====>               ] 0.050003 s
# [racon::Polisher::initialize] aligning overlaps [=====>              ] 0.056697 s
# [racon::Polisher::initialize] aligning overlaps [======>             ] 0.062778 s
# [racon::Polisher::initialize] aligning overlaps [=======>            ] 0.068564 s
# [racon::Polisher::initialize] aligning overlaps [========>           ] 0.073907 s
# [racon::Polisher::initialize] aligning overlaps [=========>          ] 0.078624 s
# [racon::Polisher::initialize] aligning overlaps [==========>         ] 0.083080 s
# [racon::Polisher::initialize] aligning overlaps [===========>        ] 0.087323 s
# [racon::Polisher::initialize] aligning overlaps [============>       ] 0.091805 s
# [racon::Polisher::initialize] aligning overlaps [=============>      ] 0.095744 s
# [racon::Polisher::initialize] aligning overlaps [==============>     ] 0.099726 s
# [racon::Polisher::initialize] aligning overlaps [===============>    ] 0.103258 s
# [racon::Polisher::initialize] aligning overlaps [================>   ] 0.106458 s
# [racon::Polisher::initialize] aligning overlaps [=================>  ] 0.109472 s
# [racon::Polisher::initialize] aligning overlaps [==================> ] 0.112239 s
# [racon::Polisher::initialize] aligning overlaps [===================>] 0.115159 s
# [racon::Polisher::initialize] aligning overlaps [====================] 0.117721 s
# [racon::Polisher::initialize] transformed data into windows 0.001803 s
# [racon::Polisher::polish] generated consensus 8.822443 s
# [racon::Polisher::] total = 8.967894 s
#
# Minimap2 alignment took 0.07 seconds.
# Total Racon iterations took 14.59 seconds.
# Total time taken for the pipeline: 14.66 seconds.
